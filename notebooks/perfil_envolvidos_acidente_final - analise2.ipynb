# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('data/perfil_envolvidos_acidente_final_2.csv', error_bad_lines=False, encoding='latin1')

# %%
df
# Out:
#        data_hora_boletim  numero_envolvido condutor desc_severidade sexo  \
# 0       31/12/2011 21:35                 1      NÃO       NAO FATAL    M
# 1       31/12/2011 22:16                 1      SIM  SEM FERIMENTOS    M
# 2       31/12/2011 22:16                 2      SIM       NAO FATAL    M
# 3       31/12/2011 22:16                 3      SIM  SEM FERIMENTOS    M
# 4       01/01/2011 00:50                 1      SIM  SEM FERIMENTOS    M
# 5       01/01/2011 00:50                 2      SIM       NAO FATAL    M
# 6       01/01/2011 00:50                 3      NÃO       NAO FATAL    M
# 7       01/01/2011 00:20                 1      SIM  SEM FERIMENTOS    M
# 8       01/01/2011 00:20                 2      NÃO       NAO FATAL    M
# 9       31/12/2011 23:39                 1      SIM       NAO FATAL    M
# 10      31/12/2011 22:27                 1      SIM  SEM FERIMENTOS    M
# 11      31/12/2011 22:27                 2      SIM       NAO FATAL    M
# ...

# %%
df.describe()
# Out:
#        numero_envolvido          Idade  indicador_pedestre  \
# count     164700.000000  164700.000000                 0.0
# mean           1.790662      32.604141                 NaN
# std            1.251995      16.624096                 NaN
# min            0.000000       0.000000                 NaN
# 25%            1.000000      23.000000                 NaN
# 50%            2.000000      31.000000                 NaN
# 75%            2.000000      43.000000                 NaN
# max           39.000000     115.000000                 NaN
#
#        indicador_passageiro  indicador_usa_capacete
# count                   0.0                     0.0
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# ...

# %%
df['desc_severidade'].describe()
# Out:
# count        155232
# unique            3
# top       NAO FATAL
# freq          90638
# Name: desc_severidade, dtype: object
